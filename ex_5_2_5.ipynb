# %% [markdown]
# <a href="https://colab.research.google.com/github/GuysBarash/ML_Workshop/blob/main/ex_5_2_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #The limit

# %% [markdown]
# f(x) = (1/2)x+1

# %%
x1 = -2
y1 = 0
x2 = 0
y2 = 1

plt.plot([x1,x2],[y1, y2])
plt.ylabel('some numbers')
plt.show()

# %%
for n in range(2,10+1):
  """f_n(x) = (1/2)((1-1/n)^2)x+(1-1/n)"""

  x1 = -(2*n)/(n-1)
  y1 = 0
  x2 = 0
  y2 = 1-(1/n)
  
  
  plt.plot([x1,x2],[y1, y2])

plt.ylabel('some numbers')
plt.show()
